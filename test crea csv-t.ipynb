# %%
import pandas as pd
import numpy as np
import nltk
import os
import nltk.corpus
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
with open("C:/Users/utilisateur/TP Scandale Enron/Projet Enron/master/cleaned_arnold-j_mails.txt", "r", encoding="utf-8") as file :
    text = file.read()

# %%
from text_functions import CleanText
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\utilisateur\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
cleanText = CleanText(text)

processed_text = cleanText.preprocessing()
#enleve les stopwords, la ponctuation, les charactères non alphanumerique

#processed_text

# %%
fdist = FreqDist(word_tokenize(processed_text))
top = fdist.most_common(20)

# %%
import matplotlib.pyplot as plt

list_mot = []
list_count = []

for word, count in top:
    list_mot.append(word)
    list_count.append(count)

    
df = pd.DataFrame(data = {'count' : list_count}, index = list_mot)

plt.figure(figsize=(30, 4))

#plt.plot(df, kind = 'bar')
df.plot(kind = 'bar')

plt.show()

# %%
liste = tokenizer.tokenize(processed_text)
for elem in liste : 
    liste[i] = lemmatizer.lemmatize(elem)
    i = i + 1
fdist = FreqDist(liste)
top = fdist.most_common(10000)

top
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b68f9b99a875> in <module>
# ----> 1 liste = tokenizer.tokenize(processed_text)
#       2 for elem in liste :
#       3     liste[i] = lemmatizer.lemmatize(elem)
#       4     i = i + 1
#       5 fdist = FreqDist(liste)
#
# NameError: name 'tokenizer' is not defined

# %%
df = pd.DataFrame.from_dict(fdist)

# %%
lemmatizer = WordNetLemmatizer()
tokenizer = RegexpTokenizer(r'\w+')
i = 0

liste = tokenizer.tokenize(text)
for elem in liste : 
    liste[i] = lemmatizer.lemmatize(elem)
    i = i + 1
fdist = FreqDist(liste)
top = fdist.most_common(10000)

# %%
#processed_text = pd.DataFrame(top,columns = ['Mot','''Nb d'apparition'''])

# %%
top.to_csv("nb_mots.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-74bb4096bdc1> in <module>
# ----> 1 top.to_csv("nb_mots.csv")
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
processed_text.set_index('Mot', inplace = True)

# %%
print (df)
# Out:
#                   Nb d'apparition
# Mot
# enron                       11940
# s                           10166
# i                            8119
# the                          6253
# to                           5980
# ...                           ...
# anheuserbuschcom                6
# usibmcom                        6
# simcoe                          6
# uswestcom                       6
# payne                           6
#
# [10000 rows x 1 columns]

# %%
# Out:
# {'those', 'most', 'out', 'again', 'o', 'against', 'be', 'itself', 'y', 'just', 'over', 'this', 'now', "it's", 'hadn', 'wouldn', 'its', 'more', 're', "shouldn't", 'down', 'her', 'aren', 'shouldn', 'or', "aren't", 'couldn', "you'd", 'until', 'other', 'few', 'very', 'below', "wouldn't", "mightn't", 'at', 'which', 'we', 'were', 'will', 'their', 'shan', 'i', 'by', "you're", 'are', 'these', 'mustn', 'ourselves', 'because', 'won', 'both', 'don', 'such', 'my', 'yours', "weren't", 'only', "hasn't", 'same', 'd', 'do', "should've", "you'll", "needn't", 'weren', 'wasn', 'how', 'isn', 'under', 'ain', 'while', 'what', "she's", 'nor', 'hers', 'when', 'after', 'they', 'all', 'myself', 'me', 'so', 'and', 'above', "doesn't", 'herself', 'm', 'once', "couldn't", 'can', 'theirs', 'as', 'doesn', 'needn', 'to', 'than', 'it', "haven't", "you've", 'am', 'who', 'the', "shan't", 'yourselves', 'into', 'doing', "don't", 't', 'further', 'should', 'is', 'during', 'yourself', 'has', "isn't", 'before', 'you', 'whom'
# ...

# %%
# Out:
#                   Nb d'apparition
# Mot
# enron                       11940
# s                           10166
# i                            8119
# the                          6253
# to                           5980
# ...                           ...
# anheuserbuschcom                6
# usibmcom                        6
# simcoe                          6
# uswestcom                       6
# payne                           6
#
# [10000 rows x 1 columns]

# %%
# Out:
# Tokenized Sentence: ["Nb d'apparition"]
